# %%
import numpy as np 
import pandas as pd

# %%
columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'car name']

data = pd.read_csv('exercise/auto-mpg.data', sep='\\s+', names=columns)

# %%
X_df = pd.read_csv('exercise/auto-mpg-features.csv')
y_df = pd.read_csv('exercise/auto-mpg-target.csv')

# %%
X = X_df.values
y = y_df.values

# %%
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge

kf = KFold(n_splits=6, shuffle=True, random_state=42)


params = {
    "alpha": np.arange(0, 1, .15)
}

ridge = Ridge()
kf = KFold(n_splits=8, shuffle=True, random_state=42)
gridsearchcv = GridSearchCV(ridge, param_grid=params, cv=kf)

gridsearchcv.fit(X, y)

print(gridsearchcv.best_params_, '/n Best score: ', gridsearchcv.best_score_)
# linreg = LinearRegression()

print(gridsearchcv.param_grid)

# cv_results = cross_val_score(linreg, X, y, cv=kf)
# Out:
# {'alpha': np.float64(0.8999999999999999)} /n Best score:  0.8024156530778439
# {'alpha': array([0.  , 0.15, 0.3 , 0.45, 0.6 , 0.75, 0.9 ])}

# %%
np.linspace(0,10, 2), np.arange(0, 1, .15)
# Out:
# (array([ 0., 10.]), array([0.  , 0.15, 0.3 , 0.45, 0.6 , 0.75, 0.9 ]))

# %%
np.mean(cv_results), np.std(cv_results)
# Out:
# (np.float64(0.8098429261299828), np.float64(0.022630462768248507))

# %% [markdown]
# ###  Lasso and Ridge Regression
# To reduce the complexity of the model, and improve its generalization

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()

X, y = housing.data, housing.target

colums = housing
X.shape, y.shape
# Out:
# ((20640, 8), (20640,))

# %%
# pd.DataFrame(housing.data, columns=columns)abs

columns, y
# Out:
# (['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)))
